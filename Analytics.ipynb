# %%
import pandas as pd
import numpy as np

# %%
June_df = pd.read_parquet("Data/yellow_tripdata_2024-06.parquet")
print(June_df.shape)
June_df.head()
# Out:
# (3539193, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2024-06-01 00:03:46   2024-06-01 00:31:23              1.0
# 1         2  2024-06-01 00:55:22   2024-06-01 01:08:24              1.0
# 2         1  2024-06-01 00:23:53   2024-06-01 00:32:35              1.0
# 3         1  2024-06-01 00:32:24   2024-06-01 00:40:06              1.0
# 4         1  2024-06-01 00:51:38   2024-06-01 00:58:17              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0          12.50         1.0                  N           138           195
# 1           4.34         1.0                  N           138             7
# 2           1.30         1.0                  N           166            41
# 3           1.20         1.0                  N           148           114
# 4           1.00         1.0                  N           148           249
#
# ...

# %%
July_df = pd.read_parquet("Data/yellow_tripdata_2024-07.parquet")
print(July_df.shape)
July_df.head()
# Out:
# (3076903, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2024-07-01 00:34:56   2024-07-01 00:46:49              1.0
# 1         2  2024-06-30 23:48:58   2024-07-01 00:28:04              1.0
# 2         2  2024-07-01 00:23:18   2024-07-01 00:29:51              1.0
# 3         1  2024-07-01 00:10:33   2024-07-01 00:27:31              0.0
# 4         1  2024-07-01 00:07:55   2024-07-01 00:34:34              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           3.20         1.0                  N           140            79
# 1          19.48         2.0                  N           132           113
# 2           1.18         1.0                  N           237           145
# 3           9.10         1.0                  N           138           164
# 4          17.70         2.0                  N           132           263
#
# ...

# %%
Aug_df = pd.read_parquet("Data/yellow_tripdata_2024-08.parquet")
print(Aug_df.shape)
Aug_df.head()
# Out:
# (2979183, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2024-08-01 00:21:00   2024-08-01 00:36:13              1.0
# 1         2  2024-08-01 00:20:01   2024-08-01 00:41:47              1.0
# 2         1  2024-08-01 00:17:52   2024-08-01 00:41:45              0.0
# 3         1  2024-08-01 00:49:08   2024-08-01 00:55:56              0.0
# 4         1  2024-08-01 00:38:52   2024-08-01 00:42:34              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           7.40         1.0                  N           138            80
# 1           9.91         1.0                  N           138           239
# 2          13.40         1.0                  N           138            88
# 3           3.90         1.0                  N           209           137
# 4           0.40         1.0                  N           148           144
#
# ...

# %%
Nov_df = pd.read_parquet("Data/yellow_tripdata_2024-11.parquet")
print(Nov_df.shape)
Nov_df.head()
# Out:
# (3646369, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-11-01 00:46:24   2024-11-01 00:57:17              1.0
# 1         2  2024-11-01 00:46:24   2024-11-01 00:57:17              1.0
# 2         1  2024-11-01 00:37:36   2024-11-01 01:28:36              1.0
# 3         2  2024-11-01 00:12:55   2024-11-01 00:22:17              2.0
# 4         2  2024-11-01 00:54:45   2024-11-01 00:59:47              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.93         1.0                  N           239           262
# 1           1.93         1.0                  N           239           263
# 2          34.30         5.0                  N           219           265
# 3           0.93         1.0                  N           186           107
# 4           0.38         1.0                  N            79            79
#
# ...

# %%
Dec_df = pd.read_parquet("Data/yellow_tripdata_2024-12.parquet")
print(Dec_df.shape)
Dec_df.head()
# Out:
# (3668371, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-12-01 00:12:27   2024-12-01 00:31:12              1.0
# 1         2  2024-11-30 23:56:04   2024-12-01 00:28:15              1.0
# 2         2  2024-12-01 00:50:35   2024-12-01 01:24:46              4.0
# 3         2  2024-12-01 00:18:16   2024-12-01 00:33:16              3.0
# 4         2  2024-12-01 00:56:13   2024-12-01 01:18:25              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           9.76         1.0                  N           138            33
# 1           7.62         1.0                  N           158            42
# 2          20.07         2.0                  N           132           236
# 3           2.34         1.0                  N           142           186
# 4           5.05         1.0                  N           107            80
#
# ...

# %%
Dec_df = pd.read_parquet("Data/yellow_tripdata_2024-12.parquet")
print(Dec_df.shape)
Dec_df.head()
